# %% [markdown]
# # Revisão de código
#
# Olá!
#
# Meu nome é Suelen. Estou feliz em revisar seu projeto hoje!
#
# Quando vejo um erro pela primeira vez, apenas aponto. Deixarei você encontrá-lo e corrigi-lo sozinho. Além disso, ao longo do texto, farei algumas observações sobre melhorias no código e também farei comentários sobre suas percepções sobre o assunto. Mas se você ainda não consegue lidar com essa tarefa, darei uma dica mais precisa na próxima iteração e também alguns exemplos práticos. Estarei aberta a feedbacks e discussões sobre o tema.
#
# Você pode encontrar meus comentários em caixas verdes, amarelas ou vermelhas como estas:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# Sucesso. Tudo está correto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# Observações. Algumas recomendações.
# </div>
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# O bloco requer algumas correções. O trabalho não pode ser aceito com os comentários vermelhos.
# </div>
#
# Você pode me responder usando isto:
#
# <div class="alert alert-block alert-info">
# <b>Resposta do aluno</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentário geral: </b> <a class="tocSkip"></a>
#
#
# Oi, Daniela! 🌟
#
# Li sua mensagem sobre o projeto e entendo completamente como ele foi desafiador e até tirou seu sono. Só queria te lembrar de uma coisa: toda grande construção começa com esforço. Esse projeto foi uma dessas pedrinhas fundamentais no castelo incrível que você está construindo, um castelo feito de dedicação, aprendizado e crescimento.
#
# É normal sentir dificuldade no começo. Eu também já estive nesse lugar, enfrentando dúvidas, erros e noites mal dormidas. E olha só, hoje conheço tanto Python que tem código que já sai direto da minha cabeça 😄 tudo porque insisti em seguir, mesmo nos momentos difíceis. E é isso que você fez também.
#
# O seu projeto ficou incrível! Dá para ver o cuidado, o empenho e a entrega em cada parte. Parabéns pelo comprometimento, pela garra e por não desistir. Você foi além da tarefa, você cresceu com ela.
#
# 👏 Parabéns, você está mais do que aprovada! Que venham os próximos desafios e as próximas conquistas!

# %% [markdown]
# # Vamos encher o carrinho!

# %% [markdown]
# # Introdução
#
# O Instacart é uma plataforma de entrega de supermercado onde os clientes podem fazer um pedido no supermercado e depois receber sua compra, semelhante ao funcionamento do Uber Eats e do iFood. O conjunto de dados que fornecemos foi modificado a partir do original. Reduzimos o tamanho dele para que seus cálculos sejam executados mais rapidamente e incluímos valores ausentes e duplicados. Também tivemos o cuidado de preservar as distribuições dos dados originais quando fizemos as alterações.
#
# Você precisa completar três etapas. Para cada uma delas, escreva uma breve introdução descrevendo como você pretende concluir a etapa e justifique suas decisões em parágrafos explicativos a medida que você avança na solução. Escreva também uma conclusão para resumir suas conclusões e escolhas.

# %% [markdown]
# ## Dicionário de dados
#
# Há cinco tabelas no conjunto de dados, e você vai precisar usar todas elas para pré-processar seus dados e fazer AED. Abaixo está um dicionário que lista as colunas de cada tabela e descreve os dados contidos nelas.
#
# - `instacart_orders.csv`: cada linha corresponde a um pedido no aplicativo da Instacart
#     - `'order_id'`: é o número que identifica cada pedido de forma exclusiva
#     - `'user_id'`: é o número de identificação exclusivo da conta de cada cliente
#     - `'order_number'`: é o número de vezes que o cliente fez um pedido
#     - `'order_dow'`: é o dia da semana em que o pedido foi feito (0 é domingo)
#     - `'order_hour_of_day'`: é a hora do dia em que o pedido foi feito
#     - `'days_since_prior_order'`: é o número de dias desde que o cliente fez seu pedido anterior
#
#
#
#
# - `products.csv`: cada linha corresponde a um produto exclusivo que os clientes podem comprar
#     - `'product_id'`: é o número de identificação unívoco de cada produto
#     - `'product_name'`: é o nome do produto
#     - `'aisle_id'`: é o número de identificação exclusivo de cada categoria de corredor do supermercado
#     - `'department_id'`: é o número de identificação exclusivo de cada categoria de departamento do supermercado
#
#
#
#
# -	`order_products.csv`: cada linha corresponde a um item incluído em um pedido
#     -	`'order_id'`: é o número que identifica cada pedido de forma exclusiva
#     -	`'product_id'`: é o número de identificação exclusivo de cada produto
#     -	`'add_to_cart_order'`: é a ordem sequencial em que cada item foi colocado no carrinho
#     -	`'reordered'`: 0 se o cliente nunca comprou o produto antes, 1 se já o comprou
#
#
#
#
# -	`aisles.csv`
#     -	`'aisle_id'`: é o número de identificação exclusivo de cada categoria de corredor do supermercado
#     -	`'aisle'`: é o nome do corredor
#
#
#
# -	`departments.csv`
#     -	`'department_id'`: é o número de identificação exclusivo de cada categoria de departamento do supermercado
#     -	`'department'`: é o nome do departamento

# %% [markdown]
# # Etapa 1. Visão geral dos dados
#
# Leia os arquivos de dados (/datasets/instacart_orders.csv, /datasets/products.csv, /datasets/aisles.csv, /datasets/departments.csv e /datasets/order_products.csv) com `pd.read_csv()` usando os parâmetros apropriados para fazer isso corretamente. Verifique as informações para cada DataFrame criado.

# %% [markdown]
# ## Plano de solução
#
# Escreva aqui seu plano para a Etapa 2. Visão geral dos dados

# %%
# Importe as bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# leia os conjuntos de dados em DataFrames
instacart_orders = pd.read_csv('/datasets/instacart_orders.csv', sep=';')
products = pd.read_csv('/datasets/products.csv', sep=';')
aisles = pd.read_csv('/datasets/aisles.csv', sep=';')
departments = pd.read_csv('/datasets/departments.csv', sep=';')
order_products = pd.read_csv('/datasets/order_products.csv', sep=';')

# %%
# imprima as informações sobre o DataFrame
print(instacart_orders.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB
# None

# %%
# imprima as informações sobre o DataFrame
print(products.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
# None

# %%
# imprima as informações sobre o DataFrame
print(aisles.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB
# None

# %%
# imprima as informações sobre o DataFrame
print(departments.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes
# None

# %%
# imprima as informações sobre o DataFrame
print(order_products.info(show_counts=True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB
# None

# %% [markdown]
# ## Conclusões
#
# Escreva aqui suas conclusões intermediárias da Etapa 1. Visão geral dos dados.
# Apos analisar as tabelas foi possivel perceber que:
# #As tabelas possuem varias colunas, mas nem todas estao completas, algumas possuem valores ausentes, a coluna days_since_prior_order creio que deveria ser transformada em int, ja que dias sao contados inteiros, mas como ha valores ausentes, o python converte para float. mas ainda nao estou certa disso.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# - Os dataframes foram carregados corretamente. Bom uso do argumento `sep=';'´
# - Foram adicionados comentários com as observações do aluno. Muito bom!

# %% [markdown]
# # Etapa 2. Preparação de dados
#
# Faça o pré-processamento dos dados da seguinte maneira:
#
# -	Verifique e corrija os tipos de dados (por exemplo, certifique-se de que as colunas de ID sejam números inteiros)
# -	Identifique e preencha valores ausentes
# -	Identifique e remova valores duplicados
#
# Certifique-se de explicar que tipos de valores ausentes e duplicados você encontrou, como você os preencheu ou removeu, por que escolheu esses métodos e por que você acha que esses valores ausentes e duplicados estavam presentes no conjunto de dados.

# %% [markdown]
# ## Plano de solução
#
# Escreva aqui seu plano para a Etapa 2. Preparação de dados:
# #Verificar e corrigir os tipos de dados, identificar e preencher os valores ausentes, remover valores duplicados

# %% [markdown]
# ## Encontre e remova valores duplicados (e descreva por que você está fazendo suas escolhas)

# %% [markdown]
# ### DataFrame `instacart_orders`

# %%
print(instacart_orders.dtypes)#verificando se os ID sao numeros inteiros
# Out:
# order_id                    int64
# user_id                     int64
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
print(instacart_orders.isnull().sum())#identificando e preenchendo os valores ausentes
# Out:
# order_id                      0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    28819
# dtype: int64

# %%
# Verificar se há pedidos duplicados
duplicados = instacart_orders.duplicated()
num_duplicados = duplicados.sum()
print(f"Há {num_duplicados} registros duplicados.")
duplicados_dados = instacart_orders[duplicados]
print(duplicados_dados.head())
# Out:
# Há 15 registros duplicados.
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 145574    794638    50898            24          3                  2
# 223105   2160484   107525            16          3                  2
# 230807   1918001   188546            14          3                  2
# 266232   1782114   106752             1          3                  2
# 273805   1112182   202304            84          3                  2
#
#         days_since_prior_order
# 145574                     2.0
# 223105                    30.0
# 230807                    16.0
# 266232                     NaN
# 273805                     6.0

# %%
instacart_orders_clean = instacart_orders.drop_duplicates()
print(f"Após remoção, o número de duplicados é: {instacart_orders_clean.duplicated().sum()}")
# Out:
# Após remoção, o número de duplicados é: 0

# %% [markdown]
# Há linhas duplicadas? Se sim, o que elas têm em comum?
# Sim, order_id pode ser que o pedido foi realizados mais de uma vez e order_id poder ser o mesmo usuario fazendo multiplos pedidos. E order_number tbm pode indicar pedidos repetidos.

# %%
# Com base nas suas conclusões,

# verifique todos os pedidos feitos às 2h da manhã nas quartas-feiras
pedidos_quarta_2h = instacart_orders[
    (instacart_orders['order_dow'] == 3) &
    (instacart_orders['order_hour_of_day'] == 2)
]
print(pedidos_quarta_2h.head())
print(f"Total de pedidos às 2h nas quartas-feiras: {len(pedidos_quarta_2h)}")
# Out:
#        order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838    2766110   162084            41          3                  2
# 5156    2190225   138285            18          3                  2
# 15506    553049    58599            13          3                  2
# 18420    382357   120200            19          3                  2
# 24691    690242    77357             2          3                  2
#
#        days_since_prior_order
# 4838                     16.0
# 5156                     11.0
# 15506                     7.0
# 18420                    11.0
# 24691                     9.0
# Total de pedidos às 2h nas quartas-feiras: 121

# %% [markdown]
# O que esse resultado quer dizer? Isso pode significar que:
# #compras recorrentes ou automatizadas;
# #pessoas que trabalham em turnos noturnos ou que tem horarios diferentes;
# #preferencia por horarios mais tranquilos para fazer os pedidos.

# %%
# Remova pedidos duplicados
instacart_orders = instacart_orders.drop_duplicates()

# %%
# Verifique as linhas duplicadas mais uma vez
duplicadas = instacart_orders[instacart_orders.duplicated()]
print(f"Número de linhas duplicadas: {duplicadas.shape[0]}")
# Out:
# Número de linhas duplicadas: 0

# %%
# Verifique novamente apenas os IDs de pedidos duplicados
duplicados_ids = instacart_orders[instacart_orders.duplicated(subset='order_id')]
print(f"Total de order_id duplicados: {duplicados_ids.shape[0]}")
duplicados_ids[['order_id']].drop_duplicates().head()
# Out:
# Total de order_id duplicados: 0
# Empty DataFrame
# Columns: [order_id]
# Index: []

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
# #Foram encontrados 15 duplicados na order_id isso pode indicar algum problema no registro automatico de pedidos
# neste horario especifico. As duplicatas foram analisadas e removidas ja que sao identicas entre si.

# %% [markdown]
# ### DataFrame `products`

# %%
# Verifique se há linhas completamente duplicadas
duplicatas_products = products[products.duplicated()]
print(duplicatas_products)
print(f'Total de linhas completamente duplicadas em products: {duplicatas_products.shape[0]}')
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []
# Total de linhas completamente duplicadas em products: 0

# %%
# Verifique apenas IDs dos produtos duplicados
prod_ids_duplicados = products[products.duplicated(subset='product_id', keep=False)]
print(f'Total de product_id duplicados: {prod_ids_duplicados["product_id"].nunique()}')
# Out:
# Total de product_id duplicados: 0

# %%
# Verifique apenas nomes de produtos duplicados (converta os nomes para minúsculas para uma comparação melhor)
products['product_name_lower'] = products['product_name'].str.lower()
produtos_duplicados = products[products.duplicated(subset='product_name_lower', keep=False)]
print(produtos_duplicados.sort_values(by='product_name_lower').head(10))
# Out:
#        product_id                               product_name  aisle_id  \
# 23339       23340  18-in-1 Hemp Peppermint Pure-Castile Soap        25
# 31844       31845  18-In-1 Hemp Peppermint Pure-Castile Soap        25
# 19941       19942            Aged Balsamic Vinegar Of Modena        19
# 13152       13153            Aged Balsamic Vinegar of Modena        19
# 24830       24831         Albacore Solid White Tuna in Water        95
# 22582       22583         Albacore Solid White Tuna In Water        95
# 9037         9038                     American Cheese slices        21
# 515           516                     American Cheese Slices        21
# 49530       49531               Anchovy Fillets In Olive Oil        95
# 12325       12326               Anchovy Fillets in Olive Oil        95
#
#        department_id                         product_name_lower
# 23339             11  18-in-1 hemp peppermint pure-castile soap
# ...

# %%
# Verifique os nomes de produtos duplicados que não estão faltando
produtos_nao_faltando = products[products['product_name'].notna()].copy()
produtos_nao_faltando['product_name_lower'] = produtos_nao_faltando['product_name'].str.lower()
produtos_duplicados_nao_faltando = produtos_nao_faltando[produtos_nao_faltando.duplicated(subset='product_name_lower', keep=False)]
print(f'Total de nomes de produtos duplicados (não faltando): {produtos_duplicados_nao_faltando["product_name_lower"].nunique()}')
print(produtos_duplicados_nao_faltando.sort_values(by='product_name_lower').head(10))
# Out:
# Total de nomes de produtos duplicados (não faltando): 103
#        product_id                               product_name  aisle_id  \
# 23339       23340  18-in-1 Hemp Peppermint Pure-Castile Soap        25
# 31844       31845  18-In-1 Hemp Peppermint Pure-Castile Soap        25
# 19941       19942            Aged Balsamic Vinegar Of Modena        19
# 13152       13153            Aged Balsamic Vinegar of Modena        19
# 24830       24831         Albacore Solid White Tuna in Water        95
# 22582       22583         Albacore Solid White Tuna In Water        95
# 9037         9038                     American Cheese slices        21
# 515           516                     American Cheese Slices        21
# 49530       49531               Anchovy Fillets In Olive Oil        95
# 12325       12326               Anchovy Fillets in Olive Oil        95
#
#        department_id                         product_name_lower
# 23339             11  18-in-1 hemp peppermint pure-castile soap
# ...

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
# #Nao havia linhas duplicadas, nao encontrei IDs duplicados, todos produtos tem IDs unicos, identifiquei duplicacao de nomes de produtos, mas isso se deve as diferencas entre maiúsculas/minúsculas. Converti todos os nomes para minúsculas para facilitar a comparacao.

# %% [markdown]
# ### DataFrame `departments`

# %%
# Verifique se há linhas completamente duplicadas
duplicatas_departments = departments[departments.duplicated()]
print(duplicatas_departments)
print(f'Total de linhas completamente duplicadas em departments: {duplicatas_departments.shape[0]}')
# Out:
# Empty DataFrame
# Columns: [department_id, department]
# Index: []
# Total de linhas completamente duplicadas em departments: 0

# %%
# Verifique apenas se há IDs dos produtos duplicados
duplicados_departments = departments[departments.duplicated(subset='department_id')]
print(duplicados_departments)
# Out:
# Empty DataFrame
# Columns: [department_id, department]
# Index: []

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
# #Nao foram encontrados Linhas, IDs ou nomes duplicados. Isto indica que os departamentos estao bem estruturados e nao ha problemas de duplicacao.

# %% [markdown]
# ### DataFrame `aisles`

# %%
# Verifique se há linhas completamente duplicadas
duplicatas_aisles = aisles[aisles.duplicated()]
print(duplicatas_aisles)
print(f'Total de linhas completamente duplicadas em aisles: {duplicatas_aisles.shape[0]}')
# Out:
# Empty DataFrame
# Columns: [aisle_id, aisle]
# Index: []
# Total de linhas completamente duplicadas em aisles: 0

# %%
# Verifique apenas se há IDs dos produtos duplicados
duplicados_aisles = aisles[aisles.duplicated(subset='aisle_id')]
print(duplicados_aisles)
# Out:
# Empty DataFrame
# Columns: [aisle_id, aisle]
# Index: []

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
# #O DataFrame aisles nao apresenta linhas ou IDs de produtos duplicados. Nao foi necessario fazer alteracoes neles.

# %% [markdown]
# ### DataFrame `order_products`

# %%
# Verifique se há linhas completamente duplicadas
duplicatas_order_products = order_products[order_products.duplicated()]
print(duplicatas_order_products)
print(f'Total de linhas completamente duplicadas em order_products: {duplicatas_order_products.shape[0]}')
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []
# Total de linhas completamente duplicadas em order_products: 0

# %%
# Verifique mais uma vez se há outros casos complicados de duplicados
duplicados_order_products = order_products[order_products.duplicated()]
print(duplicados_order_products)
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
# #Nao ha IDs duplicados no DataFrame, a associacao entre pedidos e produtos esta bem estruturada sem registros repetitivos para um unico pedido.

# %% [markdown]
# ## Encontre e remova valores ausentes
#
#
# Ao processarmos valores duplicados, observamos que também temos valores ausentes que precisamos investigar nas seguintes colunas:
#
# *	A coluna `'product_name'` da tabela products.
# *	A coluna `'days_since_prior_order'` da tabela orders.
# *	A coluna `'add_to_cart_order'` da tabela order_products.

# %% [markdown]
# ### DataFrame `products`

# %%
# Encontre valores ausentes na coluna 'product_name'
missing_product_names = products[products['product_name'].isnull()]
print(missing_product_names)
# Out:
#        product_id product_name  aisle_id  department_id product_name_lower
# 37             38          NaN       100             21                NaN
# 71             72          NaN       100             21                NaN
# 109           110          NaN       100             21                NaN
# 296           297          NaN       100             21                NaN
# 416           417          NaN       100             21                NaN
# ...           ...          ...       ...            ...                ...
# 49552       49553          NaN       100             21                NaN
# 49574       49575          NaN       100             21                NaN
# 49640       49641          NaN       100             21                NaN
# 49663       49664          NaN       100             21                NaN
# 49668       49669          NaN       100             21                NaN
#
# [1258 rows x 5 columns]

# %% [markdown]
# Descreva brevemente suas conclusões.
# #A coluna product_name tem 1258 registro sem nome de produtos. Na qual podem representar produtos sem nome ou erro na coleta ou no processamento de dados.

# %%
# Todos os nomes de produtos ausentes estão associados com o corredor de ID 100?
produtos_ausentes = products[products['product_name'].isna()]
todos_aisle_100 = produtos_ausentes['aisle_id'].eq(100).all()
if todos_aisle_100:
    print("Todos os produtos com nome ausente estão associados com o corredor de ID 100.")
else:
    print("Nem todos os produtos com nome ausente estão associados com o corredor de ID 100.")
# Out:
# Todos os produtos com nome ausente estão associados com o corredor de ID 100.

# %% [markdown]
# Descreva brevemente suas conclusões.
# #Talvez todos esses produtos tenham sido registrados de forma incompleta no sistema ou pode haver algo em comum nesses produtos como:produtos de uma categoria especifica ou caracteristicas semelhantes que justifique a ausencia de nomes.

# %%
# Todos os nomes de produtos ausentes estão associados com o departamento de ID 21?
produtos_nao_faltando = products[products['product_name'].isnull()]
produtos_nao_faltando_com_departamento = produtos_nao_faltando['department_id'].value_counts()
print(produtos_nao_faltando_com_departamento)
# Out:
# 21    1258
# Name: department_id, dtype: int64

# %% [markdown]
# Descreva brevemente suas conclusões.
# #Todos os produtos com nomes ausentes estao associados ao departamento de ID21. A ausencia de nomes de produtos pode estar relacionada a uma caracteristica especifica do departamento 21. A analise pode ajudar a entender se ha um problema na importacao de dados ou algo especifico pra ser analisado neste departamento.

# %%
# Use as tabelas department e aisle para verificar os dados do corredor com ID 100 e do departamento com ID 21.
corredor_100 = aisles[aisles['aisle_id'] == 100]
print("Dados do corredor com ID 100:")
print(corredor_100)

departamento_21 = departments[departments['department_id'] == 21]
print("\nDados do departamento com ID 21:")
print(departamento_21)
# Out:
# Dados do corredor com ID 100:
#     aisle_id    aisle
# 99       100  missing
#
# Dados do departamento com ID 21:
#     department_id department
# 20             21    missing

# %% [markdown]
# Descreva brevemente suas conclusões.
# #Os IDs 100 e 21 sao usados para indicar produtos com informacoes faltantes ou desconhecidas sobre sua localizacao ou categoria. Isso explica porque muitos produtos com 'product_name' ausentes estao associados a este ID.

# %%
# Preencha nomes de produtos ausentes com 'Unknown'
import pandas as pd
produtos = pd.read_csv('/datasets/products.csv', sep=';')
produtos['product_name'].fillna('Unknown', inplace=True)
produtos['product_name'].isnull().sum()
print(products)
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49689       49690                      HIGH PERFORMANCE ENERGY DRINK
# 49690       49691                      ORIGINAL PANCAKE & WAFFLE MIX
# 49691       49692    ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR
# 49692       49693                             SPRING WATER BODY WASH
# 49693       49694                            BURRITO- STEAK & CHEESE
#
#        aisle_id  department_id  \
# 0            61             19
# 1           104             13
# 2            94              7
# ...

# %%
produtos[produtos['product_name'] == 'Unknown'].head()
# Out:
#      product_id product_name  aisle_id  department_id
# 37           38      Unknown       100             21
# 71           72      Unknown       100             21
# 109         110      Unknown       100             21
# 296         297      Unknown       100             21
# 416         417      Unknown       100             21

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
# #Os valores ausentes na coluna product_name estavam associados a produtos com 'aisle_id'100 e 'department_id'21 ambos com o nome missing. Para corrigir, substitui os valores ausentes por 'unknown' conforme pedia o exercicio.

# %% [markdown]
# ### DataFrame `orders`

# %%
# Encontre os valores ausentes
valores_ausentes_orders = instacart_orders['days_since_prior_order'].isnull().sum()
print(f"Quantidade de valores ausentes em 'days_since_prior_order': {valores_ausentes_orders}")
# Out:
# Quantidade de valores ausentes em 'days_since_prior_order': 28817

# %%
# Há valores ausentes para os clientes que não estão fazendo o primeiro pedido?
clientes_nao_primeiro_pedido = instacart_orders[instacart_orders['order_number'] > 1]
valores_ausentes_nao_primeiro_pedido = clientes_nao_primeiro_pedido['days_since_prior_order'].isnull().sum()
print(f"Quantidade de valores ausentes em 'days_since_prior_order' para clientes que não estão fazendo o primeiro pedido: {valores_ausentes_nao_primeiro_pedido}")
# Out:
# Quantidade de valores ausentes em 'days_since_prior_order' para clientes que não estão fazendo o primeiro pedido: 0

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
# #Verfiquei se havia valores ausentes na coluna'days_since_prior_order'para clientes que nao estavam fazendo o primeiro pedido(pedidos >1).Nao encontrei valores ausentes o que significa que todos os clientes com pedidos anteriores tinham essa informacao devidamente preenchida.

# %% [markdown]
# ### DataFrame `order_products`

# %%
# Encontre os valores ausentes

print(order_products.isnull().sum())
# Out:
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64

# %%
# Quais são os valores mínimo e máximo dessa coluna?
print("Valor mínimo:", order_products['add_to_cart_order'].min())
print("Valor máximo:", order_products['add_to_cart_order'].max())
# Out:
# Valor mínimo: 1.0
# Valor máximo: 64.0

# %% [markdown]
# Descreva brevemente suas conclusões.
# #Embora a estrutura geral dos dados seja solida, uma analise complementar focada nos pedidos com mais de 20 itens poderia revelar padroes para segmentacao de clientes e otimizacao de estrategias comerciais.

# %%
# Salve todos os IDs dos pedidos com pelo menos um valor ausente em 'add_to_cart_order'
pedidos_com_valor_ausente = order_products[order_products['add_to_cart_order'].isnull()]
ids_pedidos_com_ausencia = pedidos_com_valor_ausente['order_id'].unique()
print(f"Total de pedidos com valores ausentes: {len(ids_pedidos_com_ausencia)}")
print(ids_pedidos_com_ausencia)
# Out:
# Total de pedidos com valores ausentes: 70
# [2449164 1968313 2926893 1717990 1959075  844733   61355  936852  264710
#  1564093  129627  293169 2849370 1386261 3308010  903110 2136777 3347453
#  1888628  165801 2094761 1038146 2997021  813364 2256933  171934 2409109
#  1730767 1169835  733526  404157 3125735  747668 1800005 1961723  871281
#   388234 1648217 1477139  102236 1021563 1832957 2721963  678116 1220886
#  1673227 2999801 1633337 2470674 2625444 1677118 2479011 3383594 1183255
#  1713430 2652650 1598369 1916118  854647 1302315  888470  180546 2621907
#  1308785 2729254    9310 2170451 2979697 1625713 1529171]

# %%
# Todos os pedidos com valores ausentes contêm mais de 64 produtos?
pedidos_com_ausencia = order_products[order_products['add_to_cart_order'].isnull()]

# Agrupe os pedidos com dados ausentes por ID de pedido
contagem_produtos_por_pedido = pedidos_com_ausencia.groupby('order_id')['product_id'].count()

# Conte o número de 'product_id' em cada pedido e verifique o valor mínimo da contagem
min_produtos = contagem_produtos_por_pedido.min()

print(min_produtos)
# Out:
# 1

# %% [markdown]
# Descreva brevemente suas conclusões.
# #Os valores ausentes aparecem apenas em pedidos com mais de 64 produtos. Isso pode indicar um possivel erro na hora de registrar esses pedidos.

# %%
# Substitua valores ausentes na coluna 'add_to_cart_order' por 999 e converta a coluna para o tipo integer
order_products['add_to_cart_order'] = order_products['add_to_cart_order'].fillna(999).astype(int)

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
# #Substituir os valores ausentes na referida coluna por 999 para garantir que os registros tenham um valor numerico para que a analise possa ser realizada sem erros.

# %% [markdown]
# ## Conclusões
#
# Escreva aqui suas conclusões intermediárias da Etapa 2. Preparação de dados
# #Tipos de dados: as colunas estavam corretas e os valores numericos foram mantidos como float.
# #Valores ausentes: verfiquei valores ausentes product_name, days_since_prior_order e add_to_a_cart_order na qual foi preenchida com o numero 999 para manter a consistencia de dados.
# #Valores duplicados: removi registros duplicados principalmente na tabela instacart_order e na tabela products.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# - Todos os dataframes foram processados corretamente.
# - Foram adicionados comentários com as conclusões

# %% [markdown]
# # Etapa 3. Análise de dados
#
# Quando os dados estiverem processados ​​e prontos, execute a seguinte análise:

# %% [markdown]
# # [A] Fácil (é necessário concluir tudo para passar)
#
# 1.	Verifique se os valores nas colunas `'order_hour_of_day'` e `'order_dow'` na tabela `orders` fazem sentido (ou seja, os valores da coluna  `'order_hour_of_day'` variam de 0 a 23 e os da `'order_dow'` variam de 0 a 6).
# 2.	Crie um gráfico que mostre quantas pessoas fazem pedidos a cada hora do dia.
# 3.	Crie um gráfico que mostre em que dia da semana as pessoas fazem compras.
# 4.	Crie um gráfico que mostre quanto tempo as pessoas esperam até fazer seu próximo pedido e comente sobre os valores mínimo e máximo.

# %% [markdown]
# ### [A1] Verifique se os valores fazem sentido

# %%
print("Horas únicas:", instacart_orders['order_hour_of_day'].unique())
print("Dias da semana únicos:", instacart_orders['order_dow'].unique())
# Out:
# Horas únicas: [13 12 19 20 11  8 18 15 16  9 22 10  0 14 17  1  7  6  2 21  3 23  5  4]
# Dias da semana únicos: [6 5 0 4 3 1 2]

# %% [markdown]
# Escreva suas conclusões aqui.
# #Os valores fazem sentido nas colunas 'order_hour_of_day' os valores vao de 0  a 23 representando as horas do dia. E 'oreder_dow' e estao no intervalo esperado de 0 a 6 representando os dias da semana.

# %% [markdown]
# Escreva suas conclusões aqui.

# %% [markdown]
# ### [A2] Quantas pessoas fazem pedidos a cada hora do dia?

# %%
pedidos_por_hora = instacart_orders['order_hour_of_day'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
pedidos_por_hora.plot(kind='bar', color='skyblue')
plt.title('Número de pedidos por hora do dia')
plt.xlabel('Hora do dia')
plt.ylabel('Número de pedidos')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# Escreva suas conclusões aqui.
# #O grafico mostra que o pico de pedidos por dia esta entre as 9:00 e as 16:00 horas.

# %% [markdown]
# ### [A3] Em que dia da semana as pessoas compram produtos alimentícios?

# %%
pedidos_por_dia = instacart_orders['order_dow'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
pedidos_por_dia.plot(kind='bar', color='mediumseagreen')
plt.title('Número de pedidos por dia da semana')
plt.xlabel('Dia da semana (0 = domingo, 6 = sábado)')
plt.ylabel('Número de pedidos')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# O gráfico está correto. Sugestão: Renomar o eixo 'Dia da Semana' com os valores em string representando os dias da semana. Exemplo:
# ```python
# import matplotlib.pyplot as plt
#
# # Contar o número de pedidos por dia da semana
# orders_per_dow = orders_df['order_dow'].value_counts().sort_index()
#
# # Definir os dias da semana como rótulos para o eixo x
# dow_labels = ['Segunda', 'Terça', 'Quarta', 'Quinta', 'Sexta', 'Sábado', 'Domingo']
#
# # Criar o gráfico de barras
# plt.figure(figsize=(10, 6))
# plt.bar(dow_labels, orders_per_dow, color='skyblue')
#
# # Adicionar título e rótulos dos eixos
# plt.title('Número de Pedidos por Dia da Semana')
# plt.xlabel('Dia da Semana')
# plt.ylabel('Número de Pedidos')
#
# # Exibir o gráfico
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()
# ```
# </div>

# %% [markdown]
# Escreva suas conclusões aqui.
# #'Domingo e Segunda' sao os dias que sao feitos a maioria dos pedidos, faz sentido por ser um supermercado, onde a maioria dos produtos sao 'produtos alimenticios'.

# %% [markdown]
# ### [A4] Quanto tempo as pessoas esperam até fazer outro pedido?

# %%
dias = instacart_orders['days_since_prior_order'].dropna()
plt.figure(figsize=(10, 5))
plt.hist(dias, bins=range(0, 31), edgecolor='black')
plt.title('Tempo até o próximo pedido')
plt.xlabel('Dias desde o pedido anterior')
plt.ylabel('Número de pedidos')
plt.xticks(range(0, 31))
plt.show()

# %% [markdown]
# Escreva suas conclusões aqui.
# ##Neste grafico vemos que a maioria dos pedidos sao feitos em um intervalo de 7 dias e novamente em 30 dias(maior numero de pedidos)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# Todas as tarefas de nível fácil foram realizadas corretamente.
# </div>

# %% [markdown]
# # [B] Médio (é necessário concluir tudo para passar)
#
# 1.	Há alguma diferença nas distribuições de `'order_hour_of_day'` nas quartas e sábados? Construa gráficos de barras para ambos os dias no mesmo gráfico e descreva as diferenças que você notou.
# 2.	Construa um gráfico de distribuição para o número de pedidos que os clientes fazem (ou seja, quantos clientes fizeram apenas 1 pedido, quantos fizeram apenas 2, quantos apenas 3, etc.)
# 3.	Quais são os 20 produtos comprados com mais frequência? Exiba os IDs e nomes.

# %% [markdown]
# ### [B1] Diferenças nas quartas e sábados em `'order_hour_of_day'`. Crie gráficos de barras para ambos os dias e descreva as diferenças.

# %%
quarta_feira = instacart_orders[instacart_orders['order_dow'] == 3]
sabado = instacart_orders[instacart_orders['order_dow'] == 6]
quarta_feira_por_hora = quarta_feira['order_hour_of_day'].value_counts().sort_index()
sabado_por_hora = sabado['order_hour_of_day'].value_counts().sort_index()

print(quarta_feira_por_hora)
print(sabado_por_hora)
# Out:
# 0      373
# 1      215
# 2      106
# 3      101
# 4      108
# 5      170
# 6      643
# 7     1732
# 8     3125
# 9     4490
# 10    5026
# 11    5004
# 12    4688
# 13    4674
# 14    4774
# 15    5163
# 16    4976
# 17    4175
# 18    3463
# 19    2652
# 20    1917
# 21    1450
# 22    1154
# 23     718
# Name: order_hour_of_day, dtype: int64
# 0      464
# 1      254
# 2      177
# 3      125
# 4      118
# 5      161
# 6      451
# 7     1619
# 8     3246
# 9     4311
# 10    4919
# 11    5116
# 12    5132
# 13    5323
# 14    5375
# 15    5188
# 16    5029
# 17    4295
# 18    3338
# 19    2610
# 20    1847
# 21    1473
# 22    1185
# 23     893
# Name: order_hour_of_day, dtype: int64

# %%
quarta_feira = instacart_orders[instacart_orders['order_dow'] == 3]
quarta_feira_por_hora = quarta_feira['order_hour_of_day'].value_counts().sort_index()

plt.figure(figsize=(8, 5))
plt.bar(quarta_feira_por_hora.index, quarta_feira_por_hora.values, color='blue')
plt.title('Pedidos nas Quartas-feiras por Hora do Dia')
plt.xlabel('Hora do Dia')
plt.ylabel('Número de Pedidos')
plt.xticks(range(0, 24))
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %%
sabado = instacart_orders[instacart_orders['order_dow'] == 6]
sabado_por_hora = sabado['order_hour_of_day'].value_counts().sort_index()

plt.figure(figsize=(8, 5))
plt.bar(sabado_por_hora.index, sabado_por_hora.values, color='green')
plt.title('Pedidos nos Sábados por Hora do Dia')
plt.xlabel('Hora do Dia')
plt.ylabel('Número de Pedidos')
plt.xticks(range(0, 24))
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %%
quarta_feira = instacart_orders[instacart_orders['order_dow'] == 3]
sabado = instacart_orders[instacart_orders['order_dow'] == 6]

quarta_por_hora = quarta_feira['order_hour_of_day'].value_counts().sort_index()
sabado_por_hora = sabado['order_hour_of_day'].value_counts().sort_index()
plt.figure(figsize=(10, 6))
bar_width = 0.4
horas = range(24)

plt.bar([h - bar_width/2 for h in horas], quarta_por_hora, width=bar_width, label='Quarta-feira', color='blue')
plt.bar([h + bar_width/2 for h in horas], sabado_por_hora, width=bar_width, label='Sábado', color='red')

plt.title('Comparação de Pedidos por Hora (Quarta-feira vs Sábado)')
plt.xlabel('Hora do Dia')
plt.ylabel('Número de Pedidos')
plt.xticks(horas)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# Escreva suas conclusões aqui.
# #Na quarta-feira entre as 9:00 e 11:00 sao feitos os maiores pedidos e durante o decorrer do dia novamente entre as 15:00 e as 16:00.
# #No sabado por ser fim de semana o pico fica entre as 11:00 e as 16:00. No decorrer das horas restantes os pedidos ficam quase que em equilibrio em numero de pedidos.

# %% [markdown]
# ### [B2] Qual é a distribuição do número de pedidos por cliente?

# %%
pedidos_por_cliente = instacart_orders.groupby('user_id')['order_number'].max()
print(pedidos_por_cliente.describe())
# Out:
# count    157437.000000
# mean         15.577571
# std          17.215517
# min           1.000000
# 25%           4.000000
# 50%           9.000000
# 75%          20.000000
# max         100.000000
# Name: order_number, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.hist(pedidos_por_cliente, bins=30, color='skyblue', edgecolor='black')
plt.title('Distribuição do Número de Pedidos por Cliente')
plt.xlabel('Número de Pedidos')
plt.ylabel('Quantidade de Clientes')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# Escreva suas conclusões aqui.
# #A distribuição do número de pedidos por cliente indica que a maioria dos clientes realiza poucos pedidos, enquanto uma minoria faz muitos. A mediana de 9 pedidos e a média de 15,6 refletem essa concentração nos valores mais baixos. Apenas 25% dos clientes fizeram mais de 20 pedidos, sugerindo oportunidades de fidelização e retenção para aumentar a frequência de compra dos demais.

# %% [markdown]
# ### [B3] Quais são os 20 produtos mais populares? Exiba os IDs e nomes.

# %%
produtos_populares = order_products['product_id'].value_counts().head(20).reset_index()
produtos_populares.columns = ['product_id', 'quantidade_comprada']
produtos_populares = produtos_populares.merge(products[['product_id', 'product_name']], on='product_id')

print(produtos_populares[['product_id', 'product_name']])
# Out:
#     product_id              product_name
# 0        24852                    Banana
# 1        13176    Bag of Organic Bananas
# 2        21137      Organic Strawberries
# 3        21903      Organic Baby Spinach
# 4        47209      Organic Hass Avocado
# 5        47766           Organic Avocado
# 6        47626               Large Lemon
# 7        16797              Strawberries
# 8        26209                     Limes
# 9        27845        Organic Whole Milk
# 10       27966       Organic Raspberries
# 11       22935      Organic Yellow Onion
# 12       24964            Organic Garlic
# 13       45007          Organic Zucchini
# 14       39275       Organic Blueberries
# 15       49683            Cucumber Kirby
# 16       28204        Organic Fuji Apple
# 17        5876             Organic Lemon
# 18        8277  Apple Honeycrisp Organic
# 19       40706    Organic Grape Tomatoes

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# Todas as tarefas de nível medio foram realizadas corretamente.
# </div>

# %% [markdown]
# Escreva suas conclusões aqui.
# #Os 20 produtos mais comprados sao de frutas e vegetais organicos e isso sugere que a maioria dos clientes tem uma forte preferencia por produtos frescos e naturais.

# %% [markdown]
# # [C] Difícil (é necessário concluir pelo menos duas perguntas para passar)
#
# 1.	Quantos itens as pessoas normalmente compram em um pedido? Como fica a distribuição?
# 2.	Quais são os 20 principais itens incluídos mais frequentemente em pedidos repetidos? Exiba os IDs e nomes.
# 3.	Para cada produto, qual parcela de seus pedidos são repetidos? Crie uma tabela com colunas de ID e nome do produto e a proporção de pedidos repetidos.
# 4.	Para cada cliente, qual proporção de todos os seus pedidos são repetidos?
# 5.	Quais são os 20 principais itens que as pessoas colocam nos carrinhos antes de todos os outros? Exiba o ID do produto, nome e o número de vezes que ele foi o primeiro a ser adicionado a um carrinho.

# %% [markdown]
# ### [C1] Quantos itens as pessoas normalmente compram em um pedido? Como fica a distribuição?

# %%
itens_por_pedido = order_products.groupby('order_id')['product_id'].count()
print(itens_por_pedido.describe())
# Out:
# count    450046.000000
# mean         10.098983
# std           7.540206
# min           1.000000
# 25%           5.000000
# 50%           8.000000
# 75%          14.000000
# max         127.000000
# Name: product_id, dtype: float64

# %% [markdown]
# Escreva suas conclusões aqui.
# #A maioria dos pedidos contem entre 5 e 14 itens, o pedido medio tem cerca de 10 itens,  o maior 127 produtos. Isso indica que os clientes costumam fazer pedidos moderados de itens por vez, com alguns fora da media.

# %% [markdown]
# ### [C2] Quais são os 20 principais itens incluídos com mais frequência em pedidos repetidos? Exiba os IDs e nomes.

# %%
reorders = order_products[order_products['reordered'] == 1]
top_reordered = reorders['product_id'].value_counts().head(20).reset_index()
top_reordered.columns = ['product_id', 'reorder_count']
top_reordered = top_reordered.merge(products[['product_id', 'product_name']], on='product_id')
print(top_reordered[['product_id', 'product_name']])
# Out:
#     product_id              product_name
# 0        24852                    Banana
# 1        13176    Bag of Organic Bananas
# 2        21137      Organic Strawberries
# 3        21903      Organic Baby Spinach
# 4        47209      Organic Hass Avocado
# 5        47766           Organic Avocado
# 6        27845        Organic Whole Milk
# 7        47626               Large Lemon
# 8        27966       Organic Raspberries
# 9        16797              Strawberries
# 10       26209                     Limes
# 11       22935      Organic Yellow Onion
# 12       24964            Organic Garlic
# 13       45007          Organic Zucchini
# 14       49683            Cucumber Kirby
# 15       28204        Organic Fuji Apple
# 16        8277  Apple Honeycrisp Organic
# 17       39275       Organic Blueberries
# 18        5876             Organic Lemon
# 19       49235       Organic Half & Half

# %% [markdown]
# Escreva suas conclusões aqui.
# #Em tese é a mesma pergunta acima (7.7), teve alguma diferenca na listagem de itens( esses sao os mais repetidos entre os 20 mais populares).

# %% [markdown]
# ### [C3] Para cada produto, qual parcela de todos os pedidos dele são repetidos?

# %%
total_pedidos_por_produto = order_products.groupby('product_id').size()
pedidos_repetidos_por_produto = order_products[order_products['reordered'] == 1].groupby('product_id').size()
parcelas_repetidos = pedidos_repetidos_por_produto / total_pedidos_por_produto
parcelas_repetidos_com_nome = parcelas_repetidos.reset_index().merge(products[['product_id', 'product_name']], on='product_id')
parcelas_repetidos_com_nome.columns = ['product_id', 'repeated_fraction', 'product_name']
print(parcelas_repetidos_com_nome)
# Out:
#        product_id  repeated_fraction  \
# 0               1           0.564286
# 1               2                NaN
# 2               3           0.738095
# 3               4           0.510204
# 4               7           0.500000
# ...           ...                ...
# 45568       49690           0.800000
# 45569       49691           0.430556
# 45570       49692           0.416667
# 45571       49693           0.440000
# 45572       49694           0.333333
#
#                                             product_name
# 0                             Chocolate Sandwich Cookies
# 1                                       All-Seasons Salt
# 2                   Robust Golden Unsweetened Oolong Tea
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4                         Pure Coconut Water With Orange
# ...                                                  ...
# 45568                      HIGH PERFORMANCE ENERGY DRINK
# ...

# %% [markdown]
# Escreva suas conclusões aqui.
# #A taxa de reordem ajuda a identificar os produtos mais fieis no carrinho dos consumidores, refletindo padroes de habitos e preferencias consistentes.

# %% [markdown]
# ### [C4] Para cada cliente, qual proporção de todos os seus pedidos são repetidos?

# %%
pedidos_cliente = instacart_order_products.groupby('user_id').agg(
    total_produtos=('product_id', 'count'),
    produtos_reordenados=('reordered', 'sum')
).reset_index()
pedidos_cliente['proporcao_reordenados'] = pedidos_cliente['produtos_reordenados'] / pedidos_cliente['total_produtos']

pedidos_cliente.head()
# Out:
#    user_id  total_produtos  produtos_reordenados  proporcao_reordenados
# 0        2              26                     1               0.038462
# 1        4               2                     0               0.000000
# 2        5              12                     8               0.666667
# 3        6               4                     0               0.000000
# 4        7              14                    13               0.928571

# %% [markdown]
# Escreva suas conclusões aqui.
# #Alguns clientes quase sempre repetem seus pedidos, enquanto outros raramente ou nunca o fazem. Isso demonstra padroes de recompra distintos que podem ajudar com estrategias de recomendacao e fidelizacao.

# %% [markdown]
# ### [C5] Quais são os 20 principais itens que as pessoas colocam nos carrinhos antes de todos os outros?

# %%
import pandas as pd

instacart_orders = pd.read_csv('/datasets/instacart_orders.csv', sep=';')
products = pd.read_csv('/datasets/products.csv', sep=';')
aisles = pd.read_csv('/datasets/aisles.csv', sep=';')
departments = pd.read_csv('/datasets/departments.csv', sep=';')
order_products = pd.read_csv('/datasets/order_products.csv', sep=';')

instacart_order_products = pd.merge(order_products, instacart_orders, on='order_id')
instacart_order_products = pd.merge(instacart_order_products, products[['product_id', 'product_name']], on='product_id', how='left')
primeiros_produtos = instacart_order_products[instacart_order_products['add_to_cart_order'] == 1]
top_primeiros = primeiros_produtos['product_id'].value_counts().head(20).reset_index()
top_primeiros.columns = ['product_id', 'first_added_count']
top_primeiros = top_primeiros.merge(products[['product_id', 'product_name']], on='product_id')
top_primeiros
# Out:
#     product_id  first_added_count                 product_name
# 0        24852              15563                       Banana
# 1        13176              11026       Bag of Organic Bananas
# 2        27845               4363           Organic Whole Milk
# 3        21137               3946         Organic Strawberries
# 4        47209               3390         Organic Hass Avocado
# 5        21903               3336         Organic Baby Spinach
# 6        47766               3044              Organic Avocado
# 7        19660               2336                 Spring Water
# 8        16797               2308                 Strawberries
# 9        27966               2024          Organic Raspberries
# 10       44632               1914   Sparkling Water Grapefruit
# 11       49235               1797          Organic Half & Half
# 12       47626               1737                  Large Lemon
# 13         196               1733                         Soda
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# O-TI-MO trabalho em realizar todas as tarefas dificeis. Foram realizadas perfeitamente! Parabens!
# </div>

# %% [markdown]
# Escreva suas conclusões aqui.
# #Os primeiros produtos adicionados ao carrinho tendem a ser alimentos básicos, especialmente frescos e orgânicos, o que sugere sua alta importância na rotina de compras dos consumidores.

# %% [markdown]
# # Conclusão geral do projeto:

# %% [markdown]
# Foi um projeto dificil, que me tirou o sono...mas acredito ter aprendido bastante coisas novas.
# Durante a análise dos dados, foi possível identificar e corrigir valores ausentes, remover duplicatas e padronizar nomes para facilitar comparações. A estrutura dos dados se mostrou consistente, com associações bem definidas entre pedidos, produtos, corredores e departamentos. Verificou-se que a maioria dos pedidos é feita entre 9h e 16h, com picos aos domingos e segundas. Produtos frescos e orgânicos, como bananas, abacates e leite, estão entre os mais comprados e também são frequentemente os primeiros adicionados ao carrinho, indicando preferência por itens saudáveis e essenciais. A análise também revelou padrões de recompra distintos entre os clientes, o que pode ser útil para estratégias de fidelização e recomendação.
